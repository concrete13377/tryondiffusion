# %%
from pathlib import Path
from matplotlib import pyplot as plt
import torch

imglist = Path('/mnt/datadrive/asos_dataset/80756_203404_new_algo/prepared_128/tensors_62kready').rglob('*')

# %%
for idx, i in enumerate(imglist):
    if idx > -1 and idx < 10:
        print(idx)
        tensor = torch.load(i)
        # for k,v in tensor.items():
        #     try:
        #         plt.imshow(v.permute(1,2,0))
        #         plt.show()
        #     except Exception as e:
        #         pass
        # print(tensor)
        print(tensor['garment_poses'])
        print()
        print()
# Out:
# 0
# <class 'tuple'>
# 1
# <class 'tuple'>
# 2
# <class 'tuple'>
# 3
# <class 'numpy.ndarray'>
# 4
# <class 'numpy.ndarray'>
# 5
# <class 'numpy.ndarray'>
# 6
# <class 'numpy.ndarray'>
# 7
# <class 'numpy.ndarray'>
# 8
# <class 'numpy.ndarray'>
# 9
# <class 'numpy.ndarray'>
